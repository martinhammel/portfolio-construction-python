# %%
import pandas as pd
import edhec_risk_kit_201 as erk

# %load_ext autoreload
# %autoreload 2

brka_m = brka_d.resample('M').apply(erk.compound).to_period('M')
brka_m.head()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#              BRKA
# DATE
# 1990-01 -0.140634
# 1990-02 -0.030852
# 1990-03 -0.069204
# 1990-04 -0.003717
# 1990-05  0.067164

# %%
import edhec_risk_kit_201 as erk

fff = erk.get_fff_returns()
fff.head()
# Out:
#          Mkt-RF     SMB     HML      RF
# 1926-07  0.0296 -0.0230 -0.0287  0.0022
# 1926-08  0.0264 -0.0140  0.0419  0.0025
# 1926-09  0.0036 -0.0132  0.0001  0.0023
# 1926-10 -0.0324  0.0004  0.0051  0.0032
# 1926-11  0.0253 -0.0020 -0.0035  0.0031

# %%
#stats.api for linear regression

import statsmodels.api as sm
import numpy as np

brka_excess = brka_m["1990":"2012-05"] - fff.loc["1990":"2012-05", ['RF']].values
mkt_excess = fff.loc["1990":"2012-05", ['Mkt-RF']]
exp_var = mkt_excess.copy()
exp_var["Constant"] = 1
lm = sm.OLS(brka_excess, exp_var).fit()

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   BRKA   R-squared:                       0.154
# Model:                            OLS   Adj. R-squared:                  0.150
# Method:                 Least Squares   F-statistic:                     48.45
# Date:                Sun, 31 Aug 2025   Prob (F-statistic):           2.62e-11
# Time:                        09:30:36   Log-Likelihood:                 388.47
# No. Observations:                 269   AIC:                            -772.9
# Df Residuals:                     267   BIC:                            -765.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.5402      0.078      6.961      0.000       0.387       0.693
# ...

# %%
exp_var["Value"] = fff.loc["1990":"2012-05",['HML']]
exp_var["Size"] = fff.loc["1990":"2012-05",['SMB']]
exp_var.head()
# Out:
#          Mkt-RF  Constant   Value    Size
# 1990-01 -0.0785         1  0.0087 -0.0129
# 1990-02  0.0111         1  0.0061  0.0103
# 1990-03  0.0183         1 -0.0290  0.0152
# 1990-04 -0.0336         1 -0.0255 -0.0050
# 1990-05  0.0842         1 -0.0374 -0.0257

# %%
lm = sm.OLS(brka_excess, exp_var).fit()
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   BRKA   R-squared:                       0.290
# Model:                            OLS   Adj. R-squared:                  0.282
# Method:                 Least Squares   F-statistic:                     36.06
# Date:                Sun, 31 Aug 2025   Prob (F-statistic):           1.41e-19
# Time:                        09:30:50   Log-Likelihood:                 412.09
# No. Observations:                 269   AIC:                            -816.2
# Df Residuals:                     265   BIC:                            -801.8
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.6761      0.074      9.155      0.000       0.531       0.821
# ...

# %%
brka_excess = brka_m["1990":"2018"] - fff.loc["1990":"2018", ['RF']].values
mkt_excess = fff.loc["1990":"2018", ['Mkt-RF']]
exp_var = mkt_excess.copy()
exp_var["Constant"] = 1
lm = sm.OLS(brka_excess, exp_var).fit()

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   BRKA   R-squared:                       0.181
# Model:                            OLS   Adj. R-squared:                  0.179
# Method:                 Least Squares   F-statistic:                     76.69
# Date:                Sun, 31 Aug 2025   Prob (F-statistic):           9.03e-17
# Time:                        09:10:26   Log-Likelihood:                 535.44
# No. Observations:                 348   AIC:                            -1067.
# Df Residuals:                     346   BIC:                            -1059.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.5779      0.066      8.757      0.000       0.448       0.708
# ...

# %%
exp_var["Value"] = fff.loc["1990":"2018",['HML']]
exp_var["Size"] = fff.loc["1990":"2018",['SMB']]
lm = sm.OLS(brka_excess, exp_var).fit()
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   BRKA   R-squared:                       0.317
# Model:                            OLS   Adj. R-squared:                  0.311
# Method:                 Least Squares   F-statistic:                     53.29
# Date:                Sun, 31 Aug 2025   Prob (F-statistic):           2.59e-28
# Time:                        09:11:31   Log-Likelihood:                 567.01
# No. Observations:                 348   AIC:                            -1126.
# Df Residuals:                     344   BIC:                            -1111.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.7096      0.063     11.350      0.000       0.587       0.833
# ...

# %%
brka_excess = brka_m["1990":"2000"] - fff.loc["1990":"2000", ['RF']].values
mkt_excess = fff.loc["1990":"2000", ['Mkt-RF']]
exp_var = mkt_excess.copy()
exp_var["Value"] = fff.loc["1990":"2000",['HML']]
exp_var["Size"] = fff.loc["1990":"2000",['SMB']]
lm = sm.OLS(brka_excess, exp_var).fit()
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                   BRKA   R-squared (uncentered):                   0.421
# Model:                            OLS   Adj. R-squared (uncentered):              0.408
# Method:                 Least Squares   F-statistic:                              31.28
# Date:                Sun, 31 Aug 2025   Prob (F-statistic):                    2.91e-15
# Time:                        09:18:49   Log-Likelihood:                          191.33
# No. Observations:                 132   AIC:                                     -376.7
# Df Residuals:                     129   BIC:                                     -368.0
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
# CAPM
brka_excess = brka_m["1990":"2018"] - fff.loc["1990":"2018", ['RF']].values
mkt_excess  = fff.loc["1990":"2018", ['Mkt-RF']]
exp_var = mkt_excess.copy()
exp_var["Constant"] = 1
lm = sm.OLS(brka_excess, exp_var).fit()
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   BRKA   R-squared:                       0.181
# Model:                            OLS   Adj. R-squared:                  0.179
# Method:                 Least Squares   F-statistic:                     76.69
# Date:                Sun, 31 Aug 2025   Prob (F-statistic):           9.03e-17
# Time:                        09:39:46   Log-Likelihood:                 535.44
# No. Observations:                 348   AIC:                            -1067.
# Df Residuals:                     346   BIC:                            -1059.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.5779      0.066      8.757      0.000       0.448       0.708
# ...

# %%
# Fama–French 3-factor
exp_var = mkt_excess.copy()
exp_var["Constant"] = 1
exp_var["Value"] = fff.loc["1990":"2018", ['HML']]
exp_var["Size"]  = fff.loc["1990":"2018", ['SMB']]
lm = sm.OLS(brka_excess, exp_var).fit()
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   BRKA   R-squared:                       0.317
# Model:                            OLS   Adj. R-squared:                  0.311
# Method:                 Least Squares   F-statistic:                     53.29
# Date:                Sun, 31 Aug 2025   Prob (F-statistic):           2.59e-28
# Time:                        09:40:07   Log-Likelihood:                 567.01
# No. Observations:                 348   AIC:                            -1126.
# Df Residuals:                     344   BIC:                            -1111.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.7096      0.063     11.350      0.000       0.587       0.833
# ...

# %%
# CAPM
brka_excess = brka_m["1990":"2000"] - fff.loc["1990":"2000", ['RF']].values
mkt_excess  = fff.loc["1990":"2000", ['Mkt-RF']]
exp_var = mkt_excess.copy()
exp_var["Constant"] = 1
lm = sm.OLS(brka_excess, exp_var).fit()
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   BRKA   R-squared:                       0.179
# Model:                            OLS   Adj. R-squared:                  0.173
# Method:                 Least Squares   F-statistic:                     28.37
# Date:                Sun, 31 Aug 2025   Prob (F-statistic):           4.28e-07
# Time:                        09:40:31   Log-Likelihood:                 170.83
# No. Observations:                 132   AIC:                            -337.7
# Df Residuals:                     130   BIC:                            -331.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.7446      0.140      5.326      0.000       0.468       1.021
# ...

# %%
# Fama–French 3-factor
exp_var = mkt_excess.copy()
exp_var["Constant"] = 1
exp_var["Value"] = fff.loc["1990":"2000", ['HML']]
exp_var["Size"]  = fff.loc["1990":"2000", ['SMB']]
lm = sm.OLS(brka_excess, exp_var).fit()
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   BRKA   R-squared:                       0.400
# Model:                            OLS   Adj. R-squared:                  0.386
# Method:                 Least Squares   F-statistic:                     28.45
# Date:                Sun, 31 Aug 2025   Prob (F-statistic):           3.66e-14
# Time:                        09:40:40   Log-Likelihood:                 191.52
# No. Observations:                 132   AIC:                            -375.0
# Df Residuals:                     128   BIC:                            -363.5
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         1.0704      0.137      7.786      0.000       0.798       1.342
# ...

# %%
# CAPM
brka_excess = brka_m["2000":"2010"] - fff.loc["2000":"2010", ['RF']].values
mkt_excess  = fff.loc["2000":"2010", ['Mkt-RF']]
exp_var = mkt_excess.copy()
exp_var["Constant"] = 1
lm = sm.OLS(brka_excess, exp_var).fit()
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   BRKA   R-squared:                       0.079
# Model:                            OLS   Adj. R-squared:                  0.072
# Method:                 Least Squares   F-statistic:                     11.11
# Date:                Sun, 31 Aug 2025   Prob (F-statistic):            0.00112
# Time:                        09:40:55   Log-Likelihood:                 194.78
# No. Observations:                 132   AIC:                            -385.6
# Df Residuals:                     130   BIC:                            -379.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.3318      0.100      3.333      0.001       0.135       0.529
# ...

# %%
# Fama–French 3-factor
exp_var = mkt_excess.copy()
exp_var["Constant"] = 1
exp_var["Value"] = fff.loc["2000":"2010", ['HML']]
exp_var["Size"]  = fff.loc["2000":"2010", ['SMB']]
lm = sm.OLS(brka_excess, exp_var).fit()
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   BRKA   R-squared:                       0.331
# Model:                            OLS   Adj. R-squared:                  0.315
# Method:                 Least Squares   F-statistic:                     21.09
# Date:                Sun, 31 Aug 2025   Prob (F-statistic):           3.63e-11
# Time:                        09:41:02   Log-Likelihood:                 215.88
# No. Observations:                 132   AIC:                            -423.8
# Df Residuals:                     128   BIC:                            -412.2
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.4609      0.088      5.213      0.000       0.286       0.636
# ...

# %%
# CAPM
brka_excess = brka_m["2010":"2018"] - fff.loc["2010":"2018", ['RF']].values
mkt_excess  = fff.loc["2010":"2018", ['Mkt-RF']]
exp_var = mkt_excess.copy()
exp_var["Constant"] = 1
lm = sm.OLS(brka_excess, exp_var).fit()
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   BRKA   R-squared:                       0.226
# Model:                            OLS   Adj. R-squared:                  0.219
# Method:                 Least Squares   F-statistic:                     31.02
# Date:                Sun, 31 Aug 2025   Prob (F-statistic):           1.95e-07
# Time:                        09:41:10   Log-Likelihood:                 202.19
# No. Observations:                 108   AIC:                            -400.4
# Df Residuals:                     106   BIC:                            -395.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.5446      0.098      5.570      0.000       0.351       0.738
# ...

# %%
# Fama–French 3-factor
exp_var = mkt_excess.copy()
exp_var["Constant"] = 1
exp_var["Value"] = fff.loc["2010":"2018", ['HML']]
exp_var["Size"]  = fff.loc["2010":"2018", ['SMB']]
lm = sm.OLS(brka_excess, exp_var).fit()
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   BRKA   R-squared:                       0.277
# Model:                            OLS   Adj. R-squared:                  0.257
# Method:                 Least Squares   F-statistic:                     13.31
# Date:                Sun, 31 Aug 2025   Prob (F-statistic):           2.02e-07
# Time:                        12:44:36   Log-Likelihood:                 205.88
# No. Observations:                 108   AIC:                            -403.8
# Df Residuals:                     104   BIC:                            -393.0
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.6144      0.103      5.969      0.000       0.410       0.819
# ...
